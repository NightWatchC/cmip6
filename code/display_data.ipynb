# %%
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "code":
    PROJECT_ROOT = PROJECT_ROOT.parent

# Centroids-based temperature data
output_dir = PROJECT_ROOT / "output"

# Overlapping temperature data
overlap_dir = PROJECT_ROOT / "output_overlap"
overlap_dir_weight = PROJECT_ROOT / "output_overlap" / "weights"

# %%
FGOAL_g3_ssp245 = output_dir / "FGOALS-g3_ssp245_county_daily_tas.parquet"
df = pd.read_parquet(FGOAL_g3_ssp245)
df.to_csv(output_dir / "FGOALS-g3_ssp245_county_daily_tas.csv", index=False)

# %%
# Overlap weight display
FGOAL_g3_weight = overlap_dir_weight / "FGOALS-g3_gn_overlap_weights.parquet"
df_weight = pd.read_parquet(FGOAL_g3_weight)
