# %%
import pandas as pd
import os
import sys

output_dir = r"C:\Users\NightWatch\Desktop\cmip6\output"

# %%
FGOAL_g3_ssp245 = os.path.join(output_dir, "FGOALS-g3_ssp245_county_daily_tas.parquet")
df = pd.read_parquet(FGOAL_g3_ssp245)
df.to_csv(os.path.join(output_dir, "FGOALS-g3_ssp245_county_daily_tas.csv"), index=False)
